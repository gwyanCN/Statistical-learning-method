# %% [markdown]
# ## 使用决策树(未剪枝)建立手写数字集分类模型
# ### 正确率88.09%

# %%
import numpy as np
import math 
import pandas as pd
import matplotlib.pyplot as plt

# %%
trainData = pd.read_csv("trainData.csv")
trainimageArr  = np.array(trainData.iloc[:,1:])
trainLabelArr = np.array(trainData.iloc[:,0])
testDataArr = np.array(pd.read_csv("testData.csv").iloc[:,1:])
testLabelArr = np.array(pd.read_csv("testData.csv").iloc[:,0])
trainimageArr.shape
# Out:
# (60000, 784)

# %% [markdown]
# ### 使用决策树构建MNIST手写数字集分类器
#
# #### 对于决策书而言,通常我们需要从根节点开始,基于某种特征筛选进行结点的扩展，那么如何选择合适的切分点便成了需要解决的问题
# #### 在决策树中引入了熵的概念: ${H(p)=\sum_{i=1}^{M}{-p_i*log(p_i)}}$
# #### 熵的物理意义即用于表示一个物体的稳定程度，通常而言熵越大其稳定性越差，熵越小其稳定性越好
# #### 此外决策树又引入了信息增益，$g(D,A)=H(D)-H(D|A)$ 其表示的含义以A为划分点的条件下,系统的区分度，通常取增益最大的那个特征作为划分点,然后对于划分过后的数据集进行再次的特征划分点选择
# #### $g(D,A)=H(D)-H(D|A)=\sum_{i=1}^{K}-\frac{|D_i|}{|D|}*log(\frac{|D_i|}{|D|}) - \sum_{i=1}^{K}\frac{|D_i|}{|D|}*\sum_{j=1}^{n}\frac{|c_ij|}{|D_i|}*log(\frac{|c_ij|}{|D_i|})$ 其中K表示为特征点取值的总类，n表示为标签所可以取得得总类

# %%
def HD(trainlableArr):
    ClassDic = set([label for label in trainlableArr])
    H_D= 0
    for i in ClassDic:
        p=trainlableArr[trainlableArr==i].size/trainlableArr.shape[0]
        H_D+=-p*np.log2(p)
    return H_D

def HD_A(trainDataArr_DevByFeature,trainlabelArr):
    H_D_A = 0
    ClassSet =  set([label for label in trainDataArr_DevByFeature])
    for i in ClassSet:
        H_D_A+=trainDataArr_DevByFeature[trainDataArr_DevByFeature==i].size / trainDataArr_DevByFeature.size*HD(trainlabelArr[trainDataArr_DevByFeature==i])
    return H_D_A

def findMaxFeature(trainDataArr,trainlableArr):
    MaxGDA = -1
    Bestdiv = -1
    H_D = HD(trainlableArr)
    featureNum = trainDataArr.shape[1]
    for i  in range(featureNum):
        trainDevFeature = trainDataArr[:,i].flatten()
        H_D_A = HD_A(trainDevFeature,trainlableArr) 
        G_D_A = H_D - H_D_A
        if G_D_A>MaxGDA:
            MaxGDA=G_D_A
            Bestdiv = i
    return Bestdiv,MaxGDA

def majorClass(labelArr):
    '''
    找到当前标签集中占数目最大的标签
    :param labelArr: 标签集
    :return: 最大的标签
    '''
    #建立字典，用于不同类别的标签技术
    classDict = {}
    #遍历所有标签
    for i in range(len(labelArr)):
        #当第一次遇到A标签时，字典内还没有A标签，这时候直接幅值加1是错误的，
        #所以需要判断字典中是否有该键，没有则创建，有就直接自增
        if labelArr[i] in classDict.keys():
            # 若在字典中存在该标签，则直接加1
            classDict[labelArr[i]] += 1
        else:
            #若无该标签，设初值为1，表示出现了1次了
            classDict[labelArr[i]] = 1
    #对字典依据值进行降序排序
    classSort = sorted(classDict.items(), key=lambda x: x[1], reverse=True)
    #返回最大一项的标签，即占数目最多的标签
    return classSort[0][0]

# %%
def subTrainData(trainDataArr,trainLabelArr,div,index):
    newtrainDataArr = trainDataArr[trainDataArr[:,div]==index]
    newtrainLabelArr = trainLabelArr[trainDataArr[:,div]==index]
    newtrainDataArr= np.delete(newtrainDataArr,div,axis=1)
    return newtrainDataArr,newtrainLabelArr
    
def build_tree(trainDataArr, trainLabelArr):
    epsilon = 0.1 ## 最小信息增益
    featureNum = trainDataArr.shape[1]
    print("start a node",featureNum,trainDataArr.shape[0])
    classGroup = set(trainLabelArr)
    if len(classGroup)==1: ##若只剩一类，则为叶子结点，返回
        return trainLabelArr[0]
    if trainDataArr.shape[0]==1: ## 只剩一个叶子结点 则返回
        return trainLabelArr[0]
    div,maxgda = findMaxFeature(trainDataArr,trainLabelArr)
    if maxgda<epsilon:# 若信息增益小于一定的阈值 则返回类别中数量最多的一项
        return majorClass(trainLabelArr.tolist())
    tree ={div:{}}
    tree[div][0] = build_tree(*subTrainData(trainDataArr,trainLabelArr,div,0))
    tree[div][1] = build_tree(*subTrainData(trainDataArr,trainLabelArr,div,1)) 
    return tree

# %%
tree = build_tree(trainimageArr,trainLabelArr)
# Out:
# start a node 784 60000
# start a node 783 23438
# start a node 782 12033
# start a node 781 5513
# start a node 780 4196
# start a node 779 3988
# start a node 778 3795
# start a node 778 193
# start a node 777 70
# start a node 776 49
# start a node 775 33
# start a node 774 19
# start a node 773 17
# start a node 772 14
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 773 2
# start a node 774 14
# start a node 773 4
# start a node 773 10
# start a node 772 9
# start a node 772 1
# start a node 775 16
# start a node 774 11
# start a node 774 5
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 2
# start a node 776 21
# start a node 775 17
# start a node 775 4
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 2
# start a node 777 123
# start a node 776 30
# start a node 775 7
# start a node 774 5
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 23
# start a node 774 21
# start a node 773 20
# start a node 773 1
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 776 93
# start a node 775 46
# start a node 774 41
# start a node 774 5
# start a node 773 2
# start a node 773 3
# start a node 775 47
# start a node 774 30
# start a node 773 29
# start a node 772 1
# start a node 772 28
# start a node 771 5
# start a node 770 3
# start a node 770 2
# start a node 771 23
# start a node 773 1
# start a node 774 17
# start a node 773 11
# start a node 772 10
# start a node 772 1
# start a node 773 6
# start a node 779 208
# start a node 778 65
# start a node 777 31
# start a node 776 11
# start a node 775 8
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 6
# start a node 775 3
# start a node 776 20
# start a node 775 13
# start a node 775 7
# start a node 774 4
# start a node 773 1
# start a node 773 3
# start a node 774 3
# start a node 777 34
# start a node 776 29
# start a node 776 5
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 775 2
# start a node 778 143
# start a node 777 22
# start a node 776 6
# start a node 775 3
# start a node 774 1
# start a node 774 2
# start a node 775 3
# start a node 776 16
# start a node 777 121
# start a node 780 1317
# start a node 779 721
# start a node 778 580
# start a node 777 517
# start a node 776 60
# start a node 775 32
# start a node 774 24
# start a node 773 10
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 8
# start a node 771 5
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 773 14
# start a node 772 8
# start a node 771 7
# start a node 771 1
# start a node 772 6
# start a node 774 8
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 5
# start a node 775 28
# start a node 774 26
# start a node 773 16
# start a node 773 10
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 772 6
# start a node 774 2
# start a node 776 457
# start a node 777 63
# start a node 776 51
# start a node 775 41
# start a node 774 38
# start a node 773 7
# start a node 772 4
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 773 31
# start a node 774 3
# start a node 775 10
# start a node 774 8
# start a node 773 7
# start a node 773 1
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 776 12
# start a node 775 4
# start a node 774 2
# start a node 774 2
# start a node 775 8
# start a node 774 7
# start a node 774 1
# start a node 778 141
# start a node 777 49
# start a node 776 36
# start a node 775 24
# start a node 774 21
# start a node 773 17
# start a node 772 1
# start a node 772 16
# start a node 773 4
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 12
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 7
# start a node 773 4
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 776 13
# start a node 775 11
# start a node 774 10
# start a node 774 1
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 777 92
# start a node 776 25
# start a node 775 9
# start a node 774 4
# start a node 774 5
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 773 2
# start a node 775 16
# start a node 774 15
# start a node 774 1
# start a node 776 67
# start a node 775 14
# start a node 774 7
# start a node 774 7
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 775 53
# start a node 774 24
# start a node 773 10
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 773 14
# start a node 774 29
# start a node 773 23
# start a node 773 6
# start a node 772 4
# start a node 772 2
# start a node 779 596
# start a node 778 248
# start a node 777 227
# start a node 776 216
# start a node 775 209
# start a node 774 189
# start a node 773 185
# start a node 773 4
# start a node 774 20
# start a node 773 5
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 3
# start a node 773 15
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 13
# start a node 771 3
# start a node 771 10
# start a node 770 9
# start a node 770 1
# start a node 775 7
# start a node 776 11
# start a node 775 3
# start a node 775 8
# start a node 777 21
# start a node 778 348
# start a node 777 110
# start a node 776 84
# start a node 775 75
# start a node 774 65
# start a node 773 63
# start a node 772 62
# start a node 772 1
# start a node 773 2
# start a node 774 10
# start a node 773 8
# start a node 772 7
# start a node 772 1
# start a node 773 2
# start a node 775 9
# start a node 774 4
# start a node 773 1
# start a node 773 3
# start a node 774 5
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 773 2
# start a node 776 26
# start a node 775 18
# start a node 774 12
# start a node 773 5
# start a node 772 1
# start a node 772 4
# start a node 773 7
# start a node 772 6
# start a node 772 1
# start a node 774 6
# start a node 773 5
# start a node 773 1
# start a node 775 8
# start a node 774 7
# start a node 774 1
# start a node 777 238
# start a node 776 166
# start a node 775 52
# start a node 774 41
# start a node 773 31
# start a node 772 26
# start a node 771 25
# start a node 771 1
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 773 10
# start a node 774 11
# start a node 773 1
# start a node 773 10
# start a node 775 114
# start a node 774 10
# start a node 773 5
# start a node 773 5
# start a node 772 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 774 104
# start a node 773 85
# start a node 773 19
# start a node 772 17
# start a node 771 2
# start a node 771 15
# start a node 770 1
# start a node 770 14
# start a node 769 13
# start a node 769 1
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 776 72
# start a node 775 46
# start a node 774 9
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 774 37
# start a node 773 11
# start a node 773 26
# start a node 772 8
# start a node 771 5
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 772 18
# start a node 771 1
# start a node 771 17
# start a node 775 26
# start a node 774 9
# start a node 773 6
# start a node 772 4
# start a node 772 2
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 774 17
# start a node 773 8
# start a node 772 4
# start a node 772 4
# start a node 773 9
# start a node 781 6520
# start a node 780 1900
# start a node 779 1293
# start a node 778 729
# start a node 777 241
# start a node 776 92
# start a node 775 36
# start a node 774 11
# start a node 773 7
# start a node 773 4
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 2
# start a node 774 25
# start a node 773 17
# start a node 773 8
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 772 3
# start a node 775 56
# start a node 774 52
# start a node 773 50
# start a node 772 49
# start a node 771 48
# start a node 771 1
# start a node 772 1
# start a node 773 2
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 776 149
# start a node 775 41
# start a node 774 13
# start a node 774 28
# start a node 773 22
# start a node 772 11
# start a node 771 8
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 772 11
# start a node 773 6
# start a node 772 4
# start a node 772 2
# start a node 775 108
# start a node 774 6
# start a node 773 3
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 102
# start a node 777 488
# start a node 778 564
# start a node 777 476
# start a node 776 158
# start a node 775 142
# start a node 774 28
# start a node 773 6
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 4
# start a node 773 22
# start a node 772 6
# start a node 771 3
# start a node 771 3
# start a node 772 16
# start a node 774 114
# start a node 775 16
# start a node 774 5
# start a node 774 11
# start a node 773 10
# start a node 773 1
# start a node 776 318
# start a node 775 276
# start a node 774 163
# start a node 773 155
# start a node 772 18
# start a node 771 12
# start a node 770 10
# start a node 769 9
# start a node 769 1
# start a node 770 2
# start a node 771 6
# start a node 770 5
# start a node 770 1
# start a node 772 137
# start a node 773 8
# start a node 772 4
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 2
# start a node 772 4
# start a node 771 2
# start a node 771 2
# start a node 774 113
# start a node 773 51
# start a node 772 19
# start a node 771 8
# start a node 770 7
# start a node 770 1
# start a node 771 11
# start a node 770 2
# start a node 770 9
# start a node 772 32
# start a node 771 1
# start a node 771 31
# start a node 773 62
# start a node 772 54
# start a node 771 30
# start a node 770 9
# start a node 770 21
# start a node 769 4
# start a node 768 3
# start a node 768 1
# start a node 769 17
# start a node 768 16
# start a node 767 12
# start a node 766 6
# start a node 765 5
# start a node 765 1
# start a node 766 6
# start a node 767 4
# start a node 768 1
# start a node 771 24
# start a node 770 14
# start a node 769 11
# start a node 769 3
# start a node 768 1
# start a node 768 2
# start a node 770 10
# start a node 769 6
# start a node 768 2
# start a node 768 4
# start a node 769 4
# start a node 768 1
# start a node 768 3
# start a node 772 8
# start a node 771 2
# start a node 771 6
# start a node 775 42
# start a node 774 17
# start a node 773 9
# start a node 773 8
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 772 4
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 2
# start a node 774 25
# start a node 773 7
# start a node 772 6
# start a node 772 1
# start a node 773 18
# start a node 777 88
# start a node 776 10
# start a node 775 6
# start a node 775 4
# start a node 774 3
# start a node 774 1
# start a node 776 78
# start a node 775 11
# start a node 774 5
# start a node 773 2
# start a node 773 3
# start a node 774 6
# start a node 773 5
# start a node 773 1
# start a node 775 67
# start a node 774 66
# start a node 774 1
# start a node 779 607
# start a node 778 444
# start a node 777 295
# start a node 776 281
# start a node 775 88
# start a node 774 30
# start a node 773 20
# start a node 772 1
# start a node 772 19
# start a node 771 14
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 770 10
# start a node 771 5
# start a node 770 1
# start a node 770 4
# start a node 773 10
# start a node 772 7
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 774 58
# start a node 773 56
# start a node 772 54
# start a node 772 2
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 775 193
# start a node 774 35
# start a node 773 7
# start a node 772 2
# start a node 772 5
# start a node 773 28
# start a node 772 23
# start a node 772 5
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 2
# start a node 774 158
# start a node 776 14
# start a node 775 6
# start a node 775 8
# start a node 774 2
# start a node 774 6
# start a node 773 2
# start a node 773 4
# start a node 777 149
# start a node 776 94
# start a node 775 69
# start a node 774 28
# start a node 773 6
# start a node 772 1
# start a node 772 5
# start a node 773 22
# start a node 772 6
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 772 16
# start a node 774 41
# start a node 773 20
# start a node 772 1
# start a node 772 19
# start a node 773 21
# start a node 772 13
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 771 9
# start a node 770 8
# start a node 770 1
# start a node 772 8
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 6
# start a node 775 25
# start a node 774 13
# start a node 773 6
# start a node 772 4
# start a node 772 2
# start a node 773 7
# start a node 772 6
# start a node 772 1
# start a node 774 12
# start a node 773 11
# start a node 773 1
# start a node 776 55
# start a node 775 34
# start a node 774 27
# start a node 773 26
# start a node 773 1
# start a node 774 7
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 5
# start a node 775 21
# start a node 774 6
# start a node 773 5
# start a node 773 1
# start a node 774 15
# start a node 773 14
# start a node 773 1
# start a node 778 163
# start a node 780 4620
# start a node 779 812
# start a node 778 560
# start a node 777 491
# start a node 776 157
# start a node 775 33
# start a node 774 26
# start a node 773 8
# start a node 773 18
# start a node 772 16
# start a node 771 14
# start a node 771 2
# start a node 772 2
# start a node 774 7
# start a node 773 6
# start a node 773 1
# start a node 775 124
# start a node 774 40
# start a node 773 23
# start a node 772 21
# start a node 771 20
# start a node 771 1
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 17
# start a node 772 15
# start a node 771 12
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 772 2
# start a node 774 84
# start a node 773 82
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 776 334
# start a node 777 69
# start a node 776 34
# start a node 775 25
# start a node 774 24
# start a node 774 1
# start a node 775 9
# start a node 774 7
# start a node 773 6
# start a node 773 1
# start a node 774 2
# start a node 776 35
# start a node 775 14
# start a node 774 8
# start a node 774 6
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 3
# start a node 775 21
# start a node 774 4
# start a node 774 17
# start a node 773 16
# start a node 773 1
# start a node 778 252
# start a node 777 225
# start a node 776 59
# start a node 775 37
# start a node 774 27
# start a node 773 20
# start a node 772 19
# start a node 772 1
# start a node 773 7
# start a node 772 1
# start a node 772 6
# start a node 774 10
# start a node 773 6
# start a node 772 5
# start a node 772 1
# start a node 773 4
# start a node 775 22
# start a node 774 13
# start a node 773 12
# start a node 773 1
# start a node 774 9
# start a node 773 5
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 776 166
# start a node 777 27
# start a node 776 8
# start a node 775 3
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 1
# start a node 775 5
# start a node 776 19
# start a node 775 18
# start a node 775 1
# start a node 779 3808
# start a node 782 11405
# start a node 781 4826
# start a node 780 3400
# start a node 779 1003
# start a node 778 690
# start a node 777 361
# start a node 776 295
# start a node 775 278
# start a node 774 263
# start a node 773 238
# start a node 772 234
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 773 25
# start a node 772 14
# start a node 772 11
# start a node 774 15
# start a node 773 7
# start a node 773 8
# start a node 772 3
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 775 17
# start a node 774 9
# start a node 774 8
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 773 4
# start a node 776 66
# start a node 775 51
# start a node 774 50
# start a node 774 1
# start a node 775 15
# start a node 774 4
# start a node 773 2
# start a node 773 2
# start a node 774 11
# start a node 773 1
# start a node 773 10
# start a node 777 329
# start a node 776 84
# start a node 775 61
# start a node 774 55
# start a node 773 13
# start a node 772 8
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 5
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 773 42
# start a node 772 27
# start a node 771 19
# start a node 770 15
# start a node 769 14
# start a node 768 1
# start a node 768 13
# start a node 769 1
# start a node 770 4
# start a node 769 3
# start a node 769 1
# start a node 771 8
# start a node 770 4
# start a node 769 1
# start a node 769 3
# start a node 770 4
# start a node 772 15
# start a node 771 12
# start a node 770 5
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 3
# start a node 770 7
# start a node 771 3
# start a node 774 6
# start a node 775 23
# start a node 774 1
# start a node 774 22
# start a node 776 245
# start a node 775 192
# start a node 774 21
# start a node 773 16
# start a node 772 13
# start a node 772 3
# start a node 773 5
# start a node 774 171
# start a node 775 53
# start a node 774 42
# start a node 773 13
# start a node 772 4
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 2
# start a node 772 9
# start a node 773 29
# start a node 772 26
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 771 22
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 774 11
# start a node 773 8
# start a node 773 3
# start a node 778 313
# start a node 777 148
# start a node 776 127
# start a node 775 121
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 774 116
# start a node 775 6
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 774 3
# start a node 776 21
# start a node 775 10
# start a node 774 7
# start a node 773 6
# start a node 773 1
# start a node 774 3
# start a node 775 11
# start a node 774 5
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 773 2
# start a node 774 6
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 4
# start a node 777 165
# start a node 776 94
# start a node 775 35
# start a node 774 25
# start a node 773 16
# start a node 772 5
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 3
# start a node 772 11
# start a node 771 10
# start a node 771 1
# start a node 773 9
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 772 4
# start a node 771 1
# start a node 771 3
# start a node 774 10
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 8
# start a node 772 1
# start a node 772 7
# start a node 775 59
# start a node 774 4
# start a node 773 1
# start a node 773 3
# start a node 774 55
# start a node 773 39
# start a node 772 1
# start a node 772 38
# start a node 773 16
# start a node 772 9
# start a node 771 8
# start a node 771 1
# start a node 772 7
# start a node 771 5
# start a node 771 2
# start a node 776 71
# start a node 775 63
# start a node 774 4
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 2
# start a node 774 59
# start a node 773 56
# start a node 772 1
# start a node 772 55
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 775 8
# start a node 774 7
# start a node 774 1
# start a node 779 2397
# start a node 778 705
# start a node 777 483
# start a node 776 426
# start a node 775 407
# start a node 774 30
# start a node 773 9
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 772 6
# start a node 773 21
# start a node 772 19
# start a node 771 18
# start a node 771 1
# start a node 772 2
# start a node 774 377
# start a node 775 19
# start a node 774 15
# start a node 773 12
# start a node 772 2
# start a node 772 10
# start a node 773 3
# start a node 774 4
# start a node 776 57
# start a node 775 22
# start a node 774 19
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 775 35
# start a node 774 30
# start a node 773 23
# start a node 772 20
# start a node 771 1
# start a node 771 19
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 773 7
# start a node 772 4
# start a node 772 3
# start a node 774 5
# start a node 773 2
# start a node 773 3
# start a node 777 222
# start a node 776 94
# start a node 775 90
# start a node 774 7
# start a node 773 4
# start a node 773 3
# start a node 774 83
# start a node 775 4
# start a node 774 2
# start a node 774 2
# start a node 776 128
# start a node 775 48
# start a node 774 41
# start a node 773 17
# start a node 772 13
# start a node 771 4
# start a node 771 9
# start a node 770 8
# start a node 770 1
# start a node 772 4
# start a node 773 24
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 772 20
# start a node 774 7
# start a node 775 80
# start a node 774 64
# start a node 773 55
# start a node 772 52
# start a node 771 9
# start a node 770 4
# start a node 769 1
# start a node 769 3
# start a node 770 5
# start a node 769 4
# start a node 769 1
# start a node 771 43
# start a node 770 39
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 772 3
# start a node 773 9
# start a node 772 5
# start a node 772 4
# start a node 771 1
# start a node 771 3
# start a node 774 16
# start a node 773 7
# start a node 772 3
# start a node 772 4
# start a node 773 9
# start a node 772 2
# start a node 772 7
# start a node 771 1
# start a node 771 6
# start a node 778 1692
# start a node 777 245
# start a node 776 130
# start a node 775 120
# start a node 774 22
# start a node 773 10
# start a node 772 9
# start a node 772 1
# start a node 773 12
# start a node 772 9
# start a node 771 8
# start a node 771 1
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 774 98
# start a node 773 79
# start a node 773 19
# start a node 772 3
# start a node 772 16
# start a node 771 13
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 775 10
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 774 7
# start a node 773 4
# start a node 773 3
# start a node 776 115
# start a node 775 30
# start a node 774 16
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 13
# start a node 774 14
# start a node 773 9
# start a node 773 5
# start a node 772 2
# start a node 772 3
# start a node 775 85
# start a node 774 45
# start a node 773 4
# start a node 772 1
# start a node 772 3
# start a node 773 41
# start a node 772 1
# start a node 772 40
# start a node 774 40
# start a node 773 23
# start a node 772 22
# start a node 771 21
# start a node 771 1
# start a node 772 1
# start a node 773 17
# start a node 772 11
# start a node 771 7
# start a node 770 5
# start a node 770 2
# start a node 771 4
# start a node 772 6
# start a node 777 1447
# start a node 776 365
# start a node 775 181
# start a node 774 166
# start a node 773 94
# start a node 772 7
# start a node 772 87
# start a node 771 82
# start a node 770 80
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 771 5
# start a node 773 72
# start a node 772 36
# start a node 771 21
# start a node 770 18
# start a node 769 10
# start a node 769 8
# start a node 768 3
# start a node 768 5
# start a node 770 3
# start a node 771 15
# start a node 770 1
# start a node 770 14
# start a node 772 36
# start a node 771 34
# start a node 770 32
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 771 2
# start a node 774 15
# start a node 773 10
# start a node 772 9
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 7
# start a node 772 1
# start a node 773 5
# start a node 772 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 775 184
# start a node 774 155
# start a node 773 134
# start a node 772 127
# start a node 772 7
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 771 4
# start a node 773 21
# start a node 772 12
# start a node 771 3
# start a node 771 9
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 7
# start a node 772 9
# start a node 771 4
# start a node 770 1
# start a node 770 3
# start a node 771 5
# start a node 774 29
# start a node 773 26
# start a node 772 9
# start a node 771 3
# start a node 771 6
# start a node 770 1
# start a node 770 5
# start a node 772 17
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 776 1082
# start a node 775 1009
# start a node 775 73
# start a node 774 31
# start a node 773 5
# start a node 772 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 26
# start a node 772 9
# start a node 772 17
# start a node 771 6
# start a node 770 1
# start a node 770 5
# start a node 771 11
# start a node 770 9
# start a node 769 1
# start a node 769 8
# start a node 770 2
# start a node 774 42
# start a node 773 23
# start a node 772 16
# start a node 771 1
# start a node 771 15
# start a node 772 7
# start a node 771 4
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 773 19
# start a node 772 4
# start a node 772 15
# start a node 771 10
# start a node 770 9
# start a node 770 1
# start a node 771 5
# start a node 770 2
# start a node 770 3
# start a node 769 1
# start a node 769 2
# start a node 780 1426
# start a node 779 608
# start a node 778 443
# start a node 777 316
# start a node 776 127
# start a node 775 106
# start a node 774 94
# start a node 773 92
# start a node 773 2
# start a node 774 12
# start a node 773 8
# start a node 773 4
# start a node 775 21
# start a node 774 2
# start a node 774 19
# start a node 776 189
# start a node 775 149
# start a node 774 43
# start a node 773 38
# start a node 772 19
# start a node 771 16
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 772 19
# start a node 771 14
# start a node 770 12
# start a node 770 2
# start a node 771 5
# start a node 770 4
# start a node 770 1
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 774 106
# start a node 773 74
# start a node 772 64
# start a node 772 10
# start a node 771 8
# start a node 770 1
# start a node 770 7
# start a node 771 2
# start a node 773 32
# start a node 772 6
# start a node 771 5
# start a node 771 1
# start a node 772 26
# start a node 771 10
# start a node 770 5
# start a node 769 3
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 770 5
# start a node 771 16
# start a node 770 14
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 12
# start a node 770 2
# start a node 775 40
# start a node 774 16
# start a node 773 6
# start a node 772 5
# start a node 772 1
# start a node 773 10
# start a node 772 8
# start a node 772 2
# start a node 774 24
# start a node 773 16
# start a node 772 11
# start a node 772 5
# start a node 771 2
# start a node 771 3
# start a node 773 8
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 772 5
# start a node 777 127
# start a node 778 165
# start a node 777 120
# start a node 776 74
# start a node 775 46
# start a node 774 40
# start a node 774 6
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 775 28
# start a node 774 18
# start a node 773 5
# start a node 773 13
# start a node 772 2
# start a node 772 11
# start a node 774 10
# start a node 773 2
# start a node 773 8
# start a node 772 1
# start a node 772 7
# start a node 776 46
# start a node 775 25
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 23
# start a node 775 21
# start a node 774 17
# start a node 773 16
# start a node 773 1
# start a node 774 4
# start a node 773 2
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 777 45
# start a node 776 23
# start a node 775 4
# start a node 775 19
# start a node 774 2
# start a node 774 17
# start a node 776 22
# start a node 775 6
# start a node 774 3
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 775 16
# start a node 779 818
# start a node 778 582
# start a node 777 400
# start a node 776 50
# start a node 775 34
# start a node 774 7
# start a node 773 4
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 27
# start a node 773 26
# start a node 773 1
# start a node 775 16
# start a node 774 13
# start a node 773 12
# start a node 773 1
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 776 350
# start a node 777 182
# start a node 776 145
# start a node 775 77
# start a node 774 11
# start a node 773 6
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 772 3
# start a node 773 5
# start a node 772 3
# start a node 772 2
# start a node 774 66
# start a node 773 37
# start a node 772 26
# start a node 771 9
# start a node 770 5
# start a node 769 3
# start a node 769 2
# start a node 770 4
# start a node 769 1
# start a node 769 3
# start a node 771 17
# start a node 772 11
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 771 7
# start a node 773 29
# start a node 772 4
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 2
# start a node 772 25
# start a node 771 20
# start a node 771 5
# start a node 770 2
# start a node 770 3
# start a node 775 68
# start a node 774 11
# start a node 773 9
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 57
# start a node 773 52
# start a node 772 8
# start a node 771 2
# start a node 771 6
# start a node 770 4
# start a node 770 2
# start a node 772 44
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 42
# start a node 770 41
# start a node 770 1
# start a node 773 5
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 772 2
# start a node 776 37
# start a node 775 30
# start a node 774 29
# start a node 773 28
# start a node 773 1
# start a node 774 1
# start a node 775 7
# start a node 774 1
# start a node 774 6
# start a node 778 236
# start a node 777 97
# start a node 776 53
# start a node 775 30
# start a node 774 9
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 774 21
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 19
# start a node 775 23
# start a node 774 6
# start a node 773 3
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 17
# start a node 773 6
# start a node 772 5
# start a node 772 1
# start a node 773 11
# start a node 772 6
# start a node 771 5
# start a node 771 1
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 776 44
# start a node 775 12
# start a node 774 10
# start a node 774 2
# start a node 775 32
# start a node 774 4
# start a node 773 2
# start a node 773 2
# start a node 774 28
# start a node 773 26
# start a node 772 24
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 2
# start a node 777 139
# start a node 776 24
# start a node 775 8
# start a node 774 4
# start a node 773 1
# start a node 773 3
# start a node 774 4
# start a node 773 1
# start a node 773 3
# start a node 775 16
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 774 13
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 11
# start a node 776 115
# start a node 775 8
# start a node 774 5
# start a node 773 2
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 3
# start a node 775 107
# start a node 774 21
# start a node 773 15
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 13
# start a node 773 6
# start a node 772 3
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 774 86
# start a node 773 82
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 781 6579
# start a node 780 2639
# start a node 779 2251
# start a node 778 953
# start a node 777 356
# start a node 776 309
# start a node 775 55
# start a node 774 26
# start a node 773 19
# start a node 772 9
# start a node 771 8
# start a node 771 1
# start a node 772 10
# start a node 771 4
# start a node 771 6
# start a node 770 5
# start a node 770 1
# start a node 773 7
# start a node 772 1
# start a node 772 6
# start a node 774 29
# start a node 773 26
# start a node 772 24
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 775 254
# start a node 776 47
# start a node 775 26
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 774 21
# start a node 773 18
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 775 21
# start a node 774 16
# start a node 773 1
# start a node 773 15
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 777 597
# start a node 776 508
# start a node 775 449
# start a node 774 52
# start a node 773 18
# start a node 772 15
# start a node 772 3
# start a node 773 34
# start a node 772 1
# start a node 772 33
# start a node 774 397
# start a node 773 325
# start a node 773 72
# start a node 772 23
# start a node 771 7
# start a node 770 4
# start a node 770 3
# start a node 769 1
# start a node 769 2
# start a node 771 16
# start a node 770 14
# start a node 770 2
# start a node 772 49
# start a node 771 43
# start a node 771 6
# start a node 770 4
# start a node 769 1
# start a node 769 3
# start a node 770 2
# start a node 775 59
# start a node 774 41
# start a node 774 18
# start a node 773 10
# start a node 772 9
# start a node 772 1
# start a node 773 8
# start a node 772 1
# start a node 772 7
# start a node 776 89
# start a node 775 54
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 774 51
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 773 47
# start a node 772 46
# start a node 772 1
# start a node 775 35
# start a node 774 10
# start a node 773 4
# start a node 773 6
# start a node 772 5
# start a node 772 1
# start a node 774 25
# start a node 773 13
# start a node 772 12
# start a node 772 1
# start a node 773 12
# start a node 772 8
# start a node 771 7
# start a node 771 1
# start a node 772 4
# start a node 771 1
# start a node 771 3
# start a node 778 1298
# start a node 777 1266
# start a node 777 32
# start a node 776 25
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 775 22
# start a node 776 7
# start a node 775 4
# start a node 774 2
# start a node 774 2
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 779 388
# start a node 778 215
# start a node 777 128
# start a node 776 29
# start a node 775 11
# start a node 774 7
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 775 18
# start a node 774 9
# start a node 773 8
# start a node 773 1
# start a node 774 9
# start a node 776 99
# start a node 775 74
# start a node 774 68
# start a node 773 67
# start a node 773 1
# start a node 774 6
# start a node 773 3
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 775 25
# start a node 774 9
# start a node 773 6
# start a node 772 2
# start a node 772 4
# start a node 773 3
# start a node 774 16
# start a node 773 5
# start a node 773 11
# start a node 772 4
# start a node 772 7
# start a node 771 6
# start a node 771 1
# start a node 777 87
# start a node 776 18
# start a node 775 9
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 774 6
# start a node 775 9
# start a node 774 1
# start a node 774 8
# start a node 776 69
# start a node 775 20
# start a node 774 18
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 49
# start a node 774 48
# start a node 774 1
# start a node 778 173
# start a node 777 60
# start a node 776 3
# start a node 775 1
# start a node 775 2
# start a node 776 57
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 775 55
# start a node 777 113
# start a node 776 58
# start a node 775 6
# start a node 775 52
# start a node 774 35
# start a node 773 1
# start a node 773 34
# start a node 774 17
# start a node 773 5
# start a node 772 2
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 773 12
# start a node 772 4
# start a node 772 8
# start a node 771 4
# start a node 771 4
# start a node 776 55
# start a node 775 9
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 775 46
# start a node 774 42
# start a node 773 33
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 30
# start a node 773 9
# start a node 772 5
# start a node 771 1
# start a node 771 4
# start a node 772 4
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 780 3940
# start a node 779 3069
# start a node 778 2290
# start a node 777 2194
# start a node 777 96
# start a node 776 62
# start a node 775 56
# start a node 774 54
# start a node 774 2
# start a node 775 6
# start a node 774 4
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 776 34
# start a node 775 3
# start a node 775 31
# start a node 774 1
# start a node 774 30
# start a node 778 779
# start a node 777 680
# start a node 776 549
# start a node 775 479
# start a node 774 78
# start a node 773 59
# start a node 772 11
# start a node 771 3
# start a node 771 8
# start a node 772 48
# start a node 773 19
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 772 16
# start a node 774 401
# start a node 775 70
# start a node 774 49
# start a node 773 44
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 774 21
# start a node 773 6
# start a node 772 3
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 773 15
# start a node 772 1
# start a node 772 14
# start a node 771 12
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 776 131
# start a node 775 37
# start a node 774 23
# start a node 774 14
# start a node 773 6
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 4
# start a node 773 8
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 5
# start a node 775 94
# start a node 777 99
# start a node 776 35
# start a node 775 12
# start a node 774 7
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 775 23
# start a node 774 17
# start a node 773 6
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 4
# start a node 773 11
# start a node 774 6
# start a node 776 64
# start a node 775 6
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 58
# start a node 774 4
# start a node 773 2
# start a node 773 2
# start a node 774 54
# start a node 779 871
# start a node 778 627
# start a node 777 147
# start a node 776 119
# start a node 775 113
# start a node 774 102
# start a node 774 11
# start a node 773 5
# start a node 772 1
# start a node 772 4
# start a node 773 6
# start a node 775 6
# start a node 776 28
# start a node 775 7
# start a node 774 6
# start a node 774 1
# start a node 775 21
# start a node 774 14
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 11
# start a node 774 7
# start a node 773 6
# start a node 773 1
# start a node 777 480
# start a node 776 116
# start a node 775 55
# start a node 774 39
# start a node 773 12
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 772 7
# start a node 773 27
# start a node 772 5
# start a node 771 2
# start a node 771 3
# start a node 772 22
# start a node 771 5
# start a node 770 3
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 1
# start a node 770 2
# start a node 771 17
# start a node 770 13
# start a node 770 4
# start a node 774 16
# start a node 773 14
# start a node 772 13
# start a node 772 1
# start a node 773 2
# start a node 775 61
# start a node 774 54
# start a node 773 46
# start a node 773 8
# start a node 772 2
# start a node 772 6
# start a node 774 7
# start a node 773 3
# start a node 773 4
# start a node 776 364
# start a node 775 52
# start a node 774 30
# start a node 773 26
# start a node 773 4
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 2
# start a node 774 22
# start a node 773 16
# start a node 772 8
# start a node 772 8
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 771 5
# start a node 773 6
# start a node 772 1
# start a node 772 5
# start a node 775 312
# start a node 774 114
# start a node 773 69
# start a node 772 29
# start a node 771 5
# start a node 770 4
# start a node 770 1
# start a node 771 24
# start a node 770 22
# start a node 769 19
# start a node 769 3
# start a node 768 1
# start a node 768 2
# start a node 770 2
# start a node 772 40
# start a node 771 19
# start a node 770 18
# start a node 770 1
# start a node 771 21
# start a node 770 7
# start a node 769 3
# start a node 769 4
# start a node 770 14
# start a node 769 7
# start a node 769 7
# start a node 768 4
# start a node 768 3
# start a node 767 1
# start a node 767 2
# start a node 773 45
# start a node 774 198
# start a node 773 158
# start a node 772 27
# start a node 771 13
# start a node 770 3
# start a node 769 1
# start a node 769 2
# start a node 770 10
# start a node 769 1
# start a node 769 9
# start a node 771 14
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 770 10
# start a node 772 131
# start a node 771 10
# start a node 770 4
# start a node 770 6
# start a node 771 121
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 770 117
# start a node 773 40
# start a node 772 26
# start a node 771 6
# start a node 771 20
# start a node 770 16
# start a node 769 2
# start a node 769 14
# start a node 768 1
# start a node 768 13
# start a node 767 12
# start a node 767 1
# start a node 770 4
# start a node 769 3
# start a node 769 1
# start a node 772 14
# start a node 771 3
# start a node 771 11
# start a node 770 10
# start a node 770 1
# start a node 778 244
# start a node 777 42
# start a node 776 15
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 775 10
# start a node 776 27
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 775 22
# start a node 774 1
# start a node 774 21
# start a node 777 202
# start a node 776 33
# start a node 775 17
# start a node 774 11
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 773 7
# start a node 774 6
# start a node 773 5
# start a node 773 1
# start a node 775 16
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 774 11
# start a node 773 4
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 2
# start a node 773 7
# start a node 776 169
# start a node 775 21
# start a node 774 9
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 773 4
# start a node 774 12
# start a node 773 5
# start a node 773 7
# start a node 772 6
# start a node 772 1
# start a node 775 148
# start a node 774 13
# start a node 773 7
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 773 6
# start a node 774 135
# start a node 783 36562
# start a node 782 19748
# start a node 781 14021
# start a node 780 4591
# start a node 779 3749
# start a node 778 1597
# start a node 777 841
# start a node 776 579
# start a node 775 388
# start a node 774 94
# start a node 773 73
# start a node 772 33
# start a node 771 22
# start a node 770 17
# start a node 769 15
# start a node 769 2
# start a node 770 5
# start a node 769 2
# start a node 769 3
# start a node 768 2
# start a node 767 1
# start a node 767 1
# start a node 768 1
# start a node 771 11
# start a node 770 10
# start a node 770 1
# start a node 772 40
# start a node 771 36
# start a node 770 34
# start a node 769 33
# start a node 769 1
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 771 4
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 2
# start a node 773 21
# start a node 772 15
# start a node 771 5
# start a node 770 3
# start a node 770 2
# start a node 771 10
# start a node 772 6
# start a node 771 1
# start a node 771 5
# start a node 774 294
# start a node 773 205
# start a node 772 176
# start a node 771 163
# start a node 770 144
# start a node 769 115
# start a node 768 9
# start a node 767 4
# start a node 766 3
# start a node 766 1
# start a node 767 5
# start a node 766 3
# start a node 766 2
# start a node 768 106
# start a node 767 88
# start a node 767 18
# start a node 766 6
# start a node 765 1
# start a node 765 5
# start a node 766 12
# start a node 765 11
# start a node 765 1
# start a node 769 29
# start a node 768 7
# start a node 768 22
# start a node 767 14
# start a node 766 1
# start a node 766 13
# start a node 767 8
# start a node 766 4
# start a node 765 1
# start a node 765 3
# start a node 766 4
# start a node 770 19
# start a node 769 12
# start a node 768 3
# start a node 768 9
# start a node 767 8
# start a node 767 1
# start a node 769 7
# start a node 768 4
# start a node 768 3
# start a node 767 2
# start a node 767 1
# start a node 771 13
# start a node 770 2
# start a node 770 11
# start a node 769 1
# start a node 769 10
# start a node 772 29
# start a node 771 28
# start a node 770 7
# start a node 769 5
# start a node 769 2
# start a node 770 21
# start a node 771 1
# start a node 773 89
# start a node 772 13
# start a node 771 4
# start a node 771 9
# start a node 770 5
# start a node 769 4
# start a node 769 1
# start a node 770 4
# start a node 772 76
# start a node 771 75
# start a node 771 1
# start a node 775 191
# start a node 774 30
# start a node 773 22
# start a node 772 1
# start a node 772 21
# start a node 773 8
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 772 5
# start a node 774 161
# start a node 773 158
# start a node 773 3
# start a node 776 262
# start a node 775 244
# start a node 774 230
# start a node 774 14
# start a node 773 5
# start a node 773 9
# start a node 772 3
# start a node 772 6
# start a node 775 18
# start a node 774 10
# start a node 773 2
# start a node 773 8
# start a node 774 8
# start a node 777 756
# start a node 776 47
# start a node 775 10
# start a node 774 4
# start a node 773 2
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 6
# start a node 773 2
# start a node 773 4
# start a node 775 37
# start a node 774 36
# start a node 774 1
# start a node 776 709
# start a node 775 697
# start a node 775 12
# start a node 774 11
# start a node 774 1
# start a node 778 2152
# start a node 777 1987
# start a node 777 165
# start a node 776 72
# start a node 775 56
# start a node 774 1
# start a node 774 55
# start a node 775 16
# start a node 774 7
# start a node 774 9
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 6
# start a node 776 93
# start a node 775 59
# start a node 774 15
# start a node 773 10
# start a node 772 9
# start a node 772 1
# start a node 773 5
# start a node 772 2
# start a node 772 3
# start a node 774 44
# start a node 773 34
# start a node 772 18
# start a node 771 1
# start a node 771 17
# start a node 772 16
# start a node 771 11
# start a node 770 5
# start a node 769 4
# start a node 769 1
# start a node 770 6
# start a node 771 5
# start a node 770 1
# start a node 770 4
# start a node 773 10
# start a node 772 6
# start a node 771 1
# start a node 771 5
# start a node 772 4
# start a node 771 1
# start a node 771 3
# start a node 775 34
# start a node 779 842
# start a node 778 404
# start a node 777 304
# start a node 776 278
# start a node 775 250
# start a node 774 234
# start a node 774 16
# start a node 773 9
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 7
# start a node 773 7
# start a node 775 28
# start a node 774 12
# start a node 773 9
# start a node 772 8
# start a node 772 1
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 16
# start a node 773 12
# start a node 772 11
# start a node 772 1
# start a node 773 4
# start a node 776 26
# start a node 775 11
# start a node 774 9
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 15
# start a node 774 12
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 773 9
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 777 100
# start a node 776 82
# start a node 775 78
# start a node 775 4
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 776 18
# start a node 775 7
# start a node 774 5
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 11
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 6
# start a node 778 438
# start a node 777 367
# start a node 776 26
# start a node 775 10
# start a node 774 8
# start a node 773 1
# start a node 773 7
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 16
# start a node 774 14
# start a node 773 13
# start a node 773 1
# start a node 774 2
# start a node 776 341
# start a node 777 71
# start a node 776 31
# start a node 775 25
# start a node 774 24
# start a node 774 1
# start a node 775 6
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 776 40
# start a node 775 14
# start a node 774 5
# start a node 774 9
# start a node 773 1
# start a node 773 8
# start a node 775 26
# start a node 774 18
# start a node 773 13
# start a node 773 5
# start a node 772 2
# start a node 772 3
# ...
# start a node 773 2
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 775 5
# start a node 777 245
# start a node 776 186
# start a node 775 135
# start a node 774 50
# start a node 773 12
# start a node 772 9
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 773 38
# start a node 772 6
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 32
# start a node 774 85
# start a node 773 72
# start a node 772 57
# start a node 771 52
# start a node 770 36
# start a node 769 26
# start a node 768 5
# start a node 768 21
# start a node 767 18
# start a node 766 15
# start a node 766 3
# start a node 765 2
# start a node 765 1
# start a node 767 3
# start a node 766 2
# start a node 766 1
# start a node 769 10
# start a node 768 8
# start a node 768 2
# start a node 770 16
# start a node 769 15
# start a node 769 1
# start a node 771 5
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 3
# start a node 772 15
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 12
# start a node 770 10
# start a node 769 1
# start a node 769 9
# start a node 770 2
# start a node 773 13
# start a node 772 5
# start a node 772 8
# start a node 775 51
# start a node 774 21
# start a node 773 20
# start a node 772 1
# start a node 772 19
# start a node 773 1
# start a node 774 30
# start a node 773 23
# start a node 772 12
# start a node 771 6
# start a node 770 5
# start a node 770 1
# start a node 771 6
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 4
# start a node 772 11
# start a node 771 10
# start a node 771 1
# start a node 773 7
# start a node 772 5
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 776 59
# start a node 775 54
# start a node 774 7
# start a node 773 3
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 774 47
# start a node 775 5
# start a node 774 3
# start a node 774 2
# start a node 778 3134
# start a node 777 348
# start a node 776 187
# start a node 775 110
# start a node 775 77
# start a node 774 59
# start a node 773 57
# start a node 772 54
# start a node 771 53
# start a node 771 1
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 773 2
# start a node 774 18
# start a node 773 16
# start a node 773 2
# start a node 776 161
# start a node 775 153
# start a node 775 8
# start a node 774 4
# start a node 774 4
# start a node 773 2
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 777 2786
# start a node 779 409
# start a node 778 260
# start a node 777 158
# start a node 776 71
# start a node 775 11
# start a node 774 5
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 2
# start a node 774 6
# start a node 773 3
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 775 60
# start a node 774 32
# start a node 773 29
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 774 28
# start a node 773 18
# start a node 772 6
# start a node 771 1
# start a node 771 5
# start a node 772 12
# start a node 771 6
# start a node 770 5
# start a node 770 1
# start a node 771 6
# start a node 773 10
# start a node 772 1
# start a node 772 9
# start a node 776 87
# start a node 775 17
# start a node 774 1
# start a node 774 16
# start a node 775 70
# start a node 774 65
# start a node 773 21
# start a node 772 20
# start a node 771 18
# start a node 770 8
# start a node 769 4
# start a node 769 4
# start a node 768 3
# start a node 768 1
# start a node 770 10
# start a node 771 2
# start a node 772 1
# start a node 773 44
# start a node 772 43
# start a node 772 1
# start a node 774 5
# start a node 773 1
# start a node 773 4
# start a node 777 102
# start a node 776 33
# start a node 775 24
# start a node 774 9
# start a node 774 15
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 773 10
# start a node 772 7
# start a node 771 6
# start a node 771 1
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 775 9
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 774 5
# start a node 776 69
# start a node 775 13
# start a node 774 11
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 56
# start a node 774 29
# start a node 773 16
# start a node 773 13
# start a node 772 8
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 6
# start a node 772 5
# start a node 774 27
# start a node 773 7
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 4
# start a node 773 20
# start a node 772 1
# start a node 772 19
# start a node 778 149
# start a node 777 122
# start a node 776 6
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 775 3
# start a node 776 116
# start a node 777 27
# start a node 776 11
# start a node 775 9
# start a node 774 8
# start a node 773 1
# start a node 773 7
# start a node 774 1
# start a node 775 2
# start a node 776 16
# start a node 775 10
# start a node 774 9
# start a node 773 1
# start a node 773 8
# start a node 774 1
# start a node 775 6
# start a node 780 3239
# start a node 779 1891
# start a node 778 1115
# start a node 777 358
# start a node 776 255
# start a node 775 85
# start a node 774 60
# start a node 773 39
# start a node 772 31
# start a node 771 4
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 2
# start a node 771 27
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 770 23
# start a node 772 8
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 773 21
# start a node 772 13
# start a node 771 5
# start a node 770 3
# start a node 769 2
# start a node 769 1
# start a node 770 2
# start a node 771 8
# start a node 772 8
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 771 5
# start a node 774 25
# start a node 773 2
# start a node 773 23
# start a node 772 21
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 775 170
# start a node 774 163
# start a node 774 7
# start a node 776 103
# start a node 775 85
# start a node 774 69
# start a node 774 16
# start a node 773 5
# start a node 773 11
# start a node 772 8
# start a node 771 7
# start a node 771 1
# start a node 772 3
# start a node 775 18
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 13
# start a node 773 6
# start a node 772 3
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 773 7
# start a node 777 757
# start a node 776 422
# start a node 775 377
# start a node 774 292
# start a node 773 283
# start a node 772 277
# start a node 772 6
# start a node 771 2
# start a node 771 4
# start a node 773 9
# start a node 772 8
# start a node 772 1
# start a node 774 85
# start a node 773 43
# start a node 772 14
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 771 10
# start a node 772 29
# start a node 771 15
# start a node 771 14
# start a node 770 6
# start a node 769 3
# start a node 769 3
# start a node 768 2
# start a node 768 1
# start a node 770 8
# start a node 769 4
# start a node 769 4
# start a node 768 3
# start a node 768 1
# start a node 773 42
# start a node 772 30
# start a node 771 15
# start a node 770 3
# start a node 770 12
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 10
# start a node 771 15
# start a node 770 11
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 9
# start a node 768 8
# start a node 768 1
# start a node 770 4
# start a node 769 3
# start a node 769 1
# start a node 772 12
# start a node 771 9
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 775 45
# start a node 774 40
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 776 335
# start a node 775 230
# start a node 774 111
# start a node 773 57
# start a node 772 14
# start a node 771 11
# start a node 770 10
# start a node 770 1
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 772 43
# start a node 771 12
# start a node 770 9
# start a node 769 5
# start a node 768 1
# start a node 768 4
# start a node 769 4
# start a node 770 3
# start a node 769 2
# start a node 769 1
# start a node 771 31
# start a node 770 18
# start a node 769 16
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 770 13
# start a node 769 9
# start a node 768 8
# start a node 768 1
# start a node 769 4
# start a node 768 3
# start a node 768 1
# start a node 773 54
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 772 51
# start a node 771 50
# start a node 771 1
# start a node 774 119
# start a node 773 110
# start a node 772 33
# start a node 771 25
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 23
# start a node 771 8
# start a node 770 6
# start a node 769 1
# start a node 769 5
# start a node 770 2
# start a node 772 77
# start a node 771 65
# start a node 770 2
# start a node 770 63
# start a node 769 60
# start a node 768 6
# start a node 767 3
# start a node 767 3
# start a node 768 54
# start a node 767 53
# start a node 767 1
# start a node 769 3
# start a node 768 1
# start a node 768 2
# start a node 771 12
# start a node 770 8
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 773 9
# start a node 772 8
# start a node 772 1
# start a node 775 105
# start a node 774 71
# start a node 773 39
# start a node 772 9
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 771 5
# start a node 770 3
# start a node 770 2
# start a node 772 30
# start a node 773 32
# start a node 772 10
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 771 6
# start a node 772 22
# start a node 771 18
# start a node 770 6
# start a node 769 3
# start a node 769 3
# start a node 768 1
# start a node 768 2
# start a node 770 12
# start a node 769 6
# start a node 768 1
# start a node 768 5
# start a node 769 6
# start a node 768 5
# start a node 768 1
# start a node 771 4
# start a node 774 34
# start a node 773 19
# start a node 772 1
# start a node 772 18
# start a node 773 15
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 10
# start a node 778 776
# start a node 777 576
# start a node 777 200
# start a node 776 82
# start a node 775 50
# start a node 774 15
# start a node 774 35
# start a node 773 8
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 5
# start a node 773 27
# start a node 772 23
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 20
# start a node 770 9
# start a node 770 11
# start a node 769 6
# start a node 769 5
# start a node 768 4
# start a node 768 1
# start a node 772 4
# start a node 775 32
# start a node 774 26
# start a node 774 6
# start a node 773 5
# start a node 773 1
# start a node 776 118
# start a node 775 32
# start a node 774 25
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 21
# start a node 774 7
# start a node 773 5
# start a node 773 2
# start a node 775 86
# start a node 774 51
# start a node 773 11
# start a node 772 2
# start a node 772 9
# start a node 771 8
# start a node 771 1
# start a node 773 40
# start a node 772 14
# start a node 771 4
# start a node 770 1
# start a node 770 3
# start a node 771 10
# start a node 770 2
# start a node 770 8
# start a node 772 26
# start a node 771 6
# start a node 770 3
# start a node 770 3
# start a node 769 1
# start a node 769 2
# start a node 771 20
# start a node 774 35
# start a node 773 14
# start a node 772 6
# start a node 771 5
# start a node 771 1
# start a node 772 8
# start a node 773 21
# start a node 779 1348
# start a node 778 769
# start a node 777 60
# start a node 776 28
# start a node 775 15
# start a node 774 11
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 773 7
# start a node 774 4
# start a node 775 13
# start a node 774 1
# start a node 774 12
# start a node 776 32
# start a node 775 12
# start a node 774 10
# start a node 773 1
# start a node 773 9
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 20
# start a node 774 19
# start a node 774 1
# start a node 777 709
# start a node 776 22
# start a node 775 13
# start a node 774 8
# start a node 773 7
# start a node 773 1
# start a node 774 5
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 3
# start a node 775 9
# start a node 774 3
# start a node 774 6
# start a node 773 3
# start a node 773 3
# start a node 776 687
# start a node 778 579
# start a node 777 198
# start a node 776 61
# start a node 775 7
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 774 4
# start a node 775 54
# start a node 776 137
# start a node 775 104
# start a node 774 88
# start a node 773 11
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 772 8
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 5
# start a node 773 77
# start a node 772 71
# start a node 771 69
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 67
# start a node 769 1
# start a node 769 66
# start a node 771 2
# start a node 772 6
# start a node 774 16
# start a node 773 13
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 775 33
# start a node 774 13
# start a node 773 8
# start a node 772 4
# start a node 771 1
# start a node 771 3
# start a node 772 4
# start a node 773 5
# start a node 774 20
# start a node 773 2
# start a node 773 18
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 15
# start a node 777 381
# start a node 776 92
# start a node 775 54
# start a node 774 25
# start a node 773 21
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 16
# start a node 771 5
# start a node 771 11
# start a node 770 1
# start a node 770 10
# start a node 769 1
# start a node 769 9
# start a node 773 4
# start a node 772 1
# start a node 772 3
# start a node 774 29
# start a node 773 27
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 775 38
# start a node 774 18
# start a node 774 20
# start a node 773 9
# start a node 772 1
# start a node 772 8
# start a node 773 11
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 9
# start a node 776 289
# start a node 775 74
# start a node 774 42
# start a node 773 5
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 772 2
# start a node 773 37
# start a node 772 7
# start a node 771 5
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 30
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 28
# start a node 770 3
# start a node 769 1
# start a node 769 2
# start a node 770 25
# start a node 774 32
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 773 27
# start a node 772 11
# start a node 771 6
# start a node 770 3
# start a node 770 3
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 1
# start a node 771 5
# start a node 772 16
# start a node 771 1
# start a node 771 15
# start a node 775 215
# start a node 774 47
# start a node 773 15
# start a node 772 11
# start a node 772 4
# start a node 771 2
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 773 32
# start a node 772 23
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 771 20
# start a node 770 19
# start a node 770 1
# start a node 772 9
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 7
# start a node 770 6
# start a node 770 1
# start a node 774 168
# start a node 773 123
# start a node 772 17
# start a node 771 4
# start a node 771 13
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 11
# start a node 769 1
# start a node 769 10
# start a node 772 106
# start a node 773 45
# start a node 772 18
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 771 15
# start a node 772 27
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 24
# start a node 770 7
# start a node 769 2
# start a node 769 5
# start a node 768 4
# start a node 768 1
# start a node 770 17
# start a node 769 1
# start a node 769 16
# start a node 768 1
# start a node 768 15

# %%
def clas(testDataArr, tree):
    while True:
        (key,value), = tree.items()
        if type(value).__name__ =="dict":
            val = testDataArr[key]
            testDataArr=np.delete(testDataArr,key)
            tree = value[val]     
            #例如{403: {0: 7, 1: {297:7}}，dataVal=0
            if type(tree).__name__!="dict":
                return tree
        else:
            return value

def predict(testDataArr,tree):
    prelabels = []
    for i in range(testDataArr.shape[0]):
        dataArr = testDataArr[i].flatten()
        label = clas(dataArr,tree)
        prelabels.append(label)
    return prelabels

# %%
pre = np.array(predict(testDataArr,tree)).flatten()
print("正确率:",np.sum(pre==testLabelArr)/testLabelArr.size*100)
# Out:
# 正确率: 88.09
